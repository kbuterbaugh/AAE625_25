# %%
import pandas as pd

Dir = r'C:\Users\DMS-3573\Documents\GitHub\AAE625_25'

df = pd.read_csv(Dir + '/AirPassengers.csv')

                 
df.columns = ['Date', 'Passengers']
print(df.head())

plt.plot(df['Date'], df['Passengers'])
plt.title('Air Pasengers')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.show()
# Out:
#       Date  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 df.columns = ['Date', 'Passengers']
#       9 print(df.head())
# ---> 11 plt.plot(df['Date'], df['Passengers'])
#      12 plt.title('Air Pasengers')
#      13 plt.xlabel('Date')
#
# NameError: name 'plt' is not defined

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
df_decom = pd.read_csv(Dir + '/AirPassengers.csv')
df_decom['Month'] = pd.to_datetime(df_decom['Month'])
df_decom.set_index('Month', inplace=True)
print(df_decom.head())

result = seasonal_decompose(df_decom['#Passengers'], model='additive')
result.plot()
plt.show()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
result = seasonal_decompose(df_decom['#Passengers'], model='multiplicative')
result.plot()
plt.show()

# %%
# pip install prophet
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    -------------------- ------------------- 6.8/13.3 MB 32.1 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 34.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 23.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/824.7 kB ? eta -:--:--
#    -------------------------------------- - 786.4/824.7 kB ? eta -:--:--
#    ---------------------------------------- 824.7/824.7 kB 1.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from prophet import Prophet

# %%
d ={'p':[1,2,3.4],'q':[1,2,3.4]}
df = pd.DataFrame(data=d)
print(d)
df['pct_q'] = df['q'].pct_change()['p'].pct_change()
print(df)
# Out:
# {'p': [1, 2, 3.4], 'q': [1, 2, 3.4]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       2 df = pd.DataFrame(data=d)
#       3 print(d)
# ----> 4 df['pct_q'] = df['q'].pct_change()['p'].pct_change()
#       5 print(df)
#
# File c:\Users\DMS-3573\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\DMS-3573\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
# ...

# %%
import pandas as pd

Dir = r'C:\Users\DMS-3573\Documents\GitHub\AAE625_25'

df = pd.read_csv(Dir + '/RetailData.csv',sep='|')
df
# Out:
#      Unnamed: 0  STORE_ID  PRICE  QUANTITY    REVENUE  \
# 0             0    177473   7.50     95104  713280.00
# 1             1    177467   7.49     94961  711257.89
# 2             2    177472   7.50     94564  709230.00
# 3             3    177484   7.51     94168  707201.68
# 4             4    177483   7.51     93898  705173.98
# ..          ...       ...    ...       ...        ...
# 286         286    178494   8.41     15881  133559.21
# 287         287    178297   6.13     21457  131531.41
# 288         288    177634   6.75     19186  129505.50
# 289         289    177615   6.90     18475  127477.50
# 290         290    177522   8.66     14486  125448.76
#
#      AVERAGE_LENGTH_OF_RESIDENCE  PERCENTAGE_OF_RENTERS  \
# 0                       6.957724               0.040098
# 1                       7.209142               0.051941
# 2                       7.348958               0.053306
# 3                       6.742886               0.058151
# ...
